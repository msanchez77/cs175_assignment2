# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs175/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs175.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs175.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs175/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs175.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs175.classifiers.linear_classifier import LinearSVM

# GIVEN
# learning_rates = [1e-9, 1e-8, 1e-7]
# regularization_strengths = [5e4, 5e5, 5e6]

learning_rates = [5e-8,6e-8,7e-8,8e-8,9e-8,1e-7]
regularization_strengths = np.linspace(5e5,5e6,num=10)

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for l in learning_rates:
    for r in regularization_strengths:
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=l,
                        reg=r, num_iters=1500)
        
        # Training set
        y_train_pred = svm.predict(X_train_feats)
        train_accuracy = np.mean(y_train == y_train_pred)
        # Validation set
        y_val_pred = svm.predict(X_val_feats)
        val_accuracy = np.mean(y_val == y_val_pred)
        
        results[(l,r)] = (train_accuracy, val_accuracy)
        
        if (val_accuracy > best_val):
            best_val = val_accuracy
            best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 5.000000e-08 reg 5.000000e+05 train accuracy: 0.304490 val accuracy: 0.333000
# lr 5.000000e-08 reg 1.000000e+06 train accuracy: 0.305347 val accuracy: 0.340000
# lr 5.000000e-08 reg 1.500000e+06 train accuracy: 0.303061 val accuracy: 0.333000
# lr 5.000000e-08 reg 2.000000e+06 train accuracy: 0.303592 val accuracy: 0.328000
# lr 5.000000e-08 reg 2.500000e+06 train accuracy: 0.310224 val accuracy: 0.338000
# lr 5.000000e-08 reg 3.000000e+06 train accuracy: 0.308020 val accuracy: 0.333000
# lr 5.000000e-08 reg 3.500000e+06 train accuracy: 0.297041 val accuracy: 0.323000
# lr 5.000000e-08 reg 4.000000e+06 train accuracy: 0.296041 val accuracy: 0.329000
# lr 5.000000e-08 reg 4.500000e+06 train accuracy: 0.304143 val accuracy: 0.343000
# lr 5.000000e-08 reg 5.000000e+06 train accuracy: 0.295796 val accuracy: 0.336000
# lr 6.000000e-08 reg 5.000000e+05 train accuracy: 0.308735 val accuracy: 0.334000
# lr 6.000000e-08 reg 1.000000e+06 train accuracy: 0.305061 val accuracy: 0.331000
# lr 6.000000e-08 reg 1.500000e+06 train accuracy: 0.308592 val accuracy: 0.342000
# lr 6.000000e-08 reg 2.000000e+06 train accuracy: 0.309306 val accuracy: 0.331000
# lr 6.000000e-08 reg 2.500000e+06 train accuracy: 0.303469 val accuracy: 0.326000
# lr 6.000000e-08 reg 3.000000e+06 train accuracy: 0.295878 val accuracy: 0.324000
# lr 6.000000e-08 reg 3.500000e+06 train accuracy: 0.299837 val accuracy: 0.320000
# lr 6.000000e-08 reg 4.000000e+06 train accuracy: 0.306388 val accuracy: 0.324000
# lr 6.000000e-08 reg 4.500000e+06 train accuracy: 0.290265 val accuracy: 0.315000
# lr 6.000000e-08 reg 5.000000e+06 train accuracy: 0.300245 val accuracy: 0.327000
# lr 7.000000e-08 reg 5.000000e+05 train accuracy: 0.310245 val accuracy: 0.341000
# lr 7.000000e-08 reg 1.000000e+06 train accuracy: 0.300551 val accuracy: 0.335000
# lr 7.000000e-08 reg 1.500000e+06 train accuracy: 0.311347 val accuracy: 0.353000
# lr 7.000000e-08 reg 2.000000e+06 train accuracy: 0.303327 val accuracy: 0.336000
# lr 7.000000e-08 reg 2.500000e+06 train accuracy: 0.302592 val accuracy: 0.335000
# lr 7.000000e-08 reg 3.000000e+06 train accuracy: 0.304531 val accuracy: 0.325000
# lr 7.000000e-08 reg 3.500000e+06 train accuracy: 0.296571 val accuracy: 0.319000
# lr 7.000000e-08 reg 4.000000e+06 train accuracy: 0.298286 val accuracy: 0.329000
# lr 7.000000e-08 reg 4.500000e+06 train accuracy: 0.298673 val accuracy: 0.329000
# lr 7.000000e-08 reg 5.000000e+06 train accuracy: 0.287612 val accuracy: 0.316000
# lr 8.000000e-08 reg 5.000000e+05 train accuracy: 0.306184 val accuracy: 0.340000
# lr 8.000000e-08 reg 1.000000e+06 train accuracy: 0.304122 val accuracy: 0.344000
# lr 8.000000e-08 reg 1.500000e+06 train accuracy: 0.306367 val accuracy: 0.326000
# lr 8.000000e-08 reg 2.000000e+06 train accuracy: 0.303327 val accuracy: 0.336000
# lr 8.000000e-08 reg 2.500000e+06 train accuracy: 0.304918 val accuracy: 0.336000
# lr 8.000000e-08 reg 3.000000e+06 train accuracy: 0.302551 val accuracy: 0.329000
# lr 8.000000e-08 reg 3.500000e+06 train accuracy: 0.305694 val accuracy: 0.334000
# lr 8.000000e-08 reg 4.000000e+06 train accuracy: 0.312531 val accuracy: 0.331000
# lr 8.000000e-08 reg 4.500000e+06 train accuracy: 0.281816 val accuracy: 0.304000
# lr 8.000000e-08 reg 5.000000e+06 train accuracy: 0.293429 val accuracy: 0.326000
# lr 9.000000e-08 reg 5.000000e+05 train accuracy: 0.307000 val accuracy: 0.330000
# lr 9.000000e-08 reg 1.000000e+06 train accuracy: 0.304265 val accuracy: 0.331000
# lr 9.000000e-08 reg 1.500000e+06 train accuracy: 0.305000 val accuracy: 0.327000
# lr 9.000000e-08 reg 2.000000e+06 train accuracy: 0.296612 val accuracy: 0.329000
# lr 9.000000e-08 reg 2.500000e+06 train accuracy: 0.294694 val accuracy: 0.317000
# lr 9.000000e-08 reg 3.000000e+06 train accuracy: 0.296673 val accuracy: 0.333000
# lr 9.000000e-08 reg 3.500000e+06 train accuracy: 0.293408 val accuracy: 0.320000
# lr 9.000000e-08 reg 4.000000e+06 train accuracy: 0.301224 val accuracy: 0.337000
# lr 9.000000e-08 reg 4.500000e+06 train accuracy: 0.308429 val accuracy: 0.343000
# lr 9.000000e-08 reg 5.000000e+06 train accuracy: 0.292388 val accuracy: 0.332000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.308143 val accuracy: 0.339000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.308571 val accuracy: 0.342000
# lr 1.000000e-07 reg 1.500000e+06 train accuracy: 0.304551 val accuracy: 0.329000
# lr 1.000000e-07 reg 2.000000e+06 train accuracy: 0.306306 val accuracy: 0.347000
# lr 1.000000e-07 reg 2.500000e+06 train accuracy: 0.291204 val accuracy: 0.323000
# lr 1.000000e-07 reg 3.000000e+06 train accuracy: 0.311878 val accuracy: 0.343000
# lr 1.000000e-07 reg 3.500000e+06 train accuracy: 0.293367 val accuracy: 0.326000
# lr 1.000000e-07 reg 4.000000e+06 train accuracy: 0.303184 val accuracy: 0.328000
# lr 1.000000e-07 reg 4.500000e+06 train accuracy: 0.292857 val accuracy: 0.318000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.297857 val accuracy: 0.308000
# best validation accuracy achieved during cross-validation: 0.353000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.319

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
# My Answer: The classifications sort of make sense, seeing how images of vehicles and animals are for the most part separated into their respective categories. I suspect some of the misclassifcations are the result of the image's colors. For example, a ship that is not surrounded by blue water is very likely to be misclassified.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print(X_train_feats.shape)
# Out:
# (49000, 155)

# %%
from cs175.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

# net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
best_val = -1

hiddenLayers = np.linspace(300,500,num=3).astype(int)
learningRates = np.linspace(0.8,1,num=3)
regStrengths = np.linspace(1e-3,1e-6,num=3)
batches = np.linspace(500,800,num=4).astype(int)

for layer in hiddenLayers:
    net = TwoLayerNet(input_dim, layer, num_classes)
    for batch in batches:
        for rate in learningRates:
            for regular in regStrengths:

                # Train the network
                stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                            num_iters=100, batch_size=batch,
                            learning_rate=rate, learning_rate_decay=0.95,
                            reg=regular, verbose=False)

                # Predict on the validation set
                val_acc = np.mean(net.predict(X_val_feats) == y_val)
                print('[Layers:', layer, '/ batch:', batch, '/ lrRate:', rate, '/ regStr:', regular, ']: ', val_acc)

                if (val_acc > best_val):
                    best_val = val_acc
                    best_net = net
                    best_layer = layer
                    best_rate = rate
                    best_reg = regular
                
print('Best validation accuracy achieved during cross-validation: %f \nwith %d layers, learning rate=%f, regularization strength=%f' % (best_val, best_layer, best_rate, best_reg))

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# [Layers: 300 / batch: 500 / lrRate: 0.8 / regStr: 0.001 ]:  0.485
# [Layers: 300 / batch: 500 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.515
# [Layers: 300 / batch: 500 / lrRate: 0.8 / regStr: 1e-06 ]:  0.54
# [Layers: 300 / batch: 500 / lrRate: 0.9 / regStr: 0.001 ]:  0.565
# [Layers: 300 / batch: 500 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.564
# [Layers: 300 / batch: 500 / lrRate: 0.9 / regStr: 1e-06 ]:  0.579
# [Layers: 300 / batch: 500 / lrRate: 1.0 / regStr: 0.001 ]:  0.58
# [Layers: 300 / batch: 500 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.563
# [Layers: 300 / batch: 500 / lrRate: 1.0 / regStr: 1e-06 ]:  0.56
# [Layers: 300 / batch: 600 / lrRate: 0.8 / regStr: 0.001 ]:  0.593
# [Layers: 300 / batch: 600 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.564
# [Layers: 300 / batch: 600 / lrRate: 0.8 / regStr: 1e-06 ]:  0.582
# [Layers: 300 / batch: 600 / lrRate: 0.9 / regStr: 0.001 ]:  0.581
# [Layers: 300 / batch: 600 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.58
# [Layers: 300 / batch: 600 / lrRate: 0.9 / regStr: 1e-06 ]:  0.565
# [Layers: 300 / batch: 600 / lrRate: 1.0 / regStr: 0.001 ]:  0.564
# [Layers: 300 / batch: 600 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.572
# [Layers: 300 / batch: 600 / lrRate: 1.0 / regStr: 1e-06 ]:  0.582
# [Layers: 300 / batch: 700 / lrRate: 0.8 / regStr: 0.001 ]:  0.576
# [Layers: 300 / batch: 700 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.588
# [Layers: 300 / batch: 700 / lrRate: 0.8 / regStr: 1e-06 ]:  0.604
# [Layers: 300 / batch: 700 / lrRate: 0.9 / regStr: 0.001 ]:  0.583
# [Layers: 300 / batch: 700 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.579
# [Layers: 300 / batch: 700 / lrRate: 0.9 / regStr: 1e-06 ]:  0.585
# [Layers: 300 / batch: 700 / lrRate: 1.0 / regStr: 0.001 ]:  0.569
# [Layers: 300 / batch: 700 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.578
# [Layers: 300 / batch: 700 / lrRate: 1.0 / regStr: 1e-06 ]:  0.555
# [Layers: 300 / batch: 800 / lrRate: 0.8 / regStr: 0.001 ]:  0.576
# [Layers: 300 / batch: 800 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.577
# [Layers: 300 / batch: 800 / lrRate: 0.8 / regStr: 1e-06 ]:  0.557
# [Layers: 300 / batch: 800 / lrRate: 0.9 / regStr: 0.001 ]:  0.57
# [Layers: 300 / batch: 800 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.558
# [Layers: 300 / batch: 800 / lrRate: 0.9 / regStr: 1e-06 ]:  0.55
# [Layers: 300 / batch: 800 / lrRate: 1.0 / regStr: 0.001 ]:  0.57
# [Layers: 300 / batch: 800 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.572
# [Layers: 300 / batch: 800 / lrRate: 1.0 / regStr: 1e-06 ]:  0.575
# [Layers: 400 / batch: 500 / lrRate: 0.8 / regStr: 0.001 ]:  0.471
# [Layers: 400 / batch: 500 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.506
# [Layers: 400 / batch: 500 / lrRate: 0.8 / regStr: 1e-06 ]:  0.538
# [Layers: 400 / batch: 500 / lrRate: 0.9 / regStr: 0.001 ]:  0.547
# [Layers: 400 / batch: 500 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.566
# [Layers: 400 / batch: 500 / lrRate: 0.9 / regStr: 1e-06 ]:  0.553
# [Layers: 400 / batch: 500 / lrRate: 1.0 / regStr: 0.001 ]:  0.567
# [Layers: 400 / batch: 500 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.583
# [Layers: 400 / batch: 500 / lrRate: 1.0 / regStr: 1e-06 ]:  0.569
# [Layers: 400 / batch: 600 / lrRate: 0.8 / regStr: 0.001 ]:  0.597
# [Layers: 400 / batch: 600 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.587
# [Layers: 400 / batch: 600 / lrRate: 0.8 / regStr: 1e-06 ]:  0.588
# [Layers: 400 / batch: 600 / lrRate: 0.9 / regStr: 0.001 ]:  0.593
# [Layers: 400 / batch: 600 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.562
# [Layers: 400 / batch: 600 / lrRate: 0.9 / regStr: 1e-06 ]:  0.581
# [Layers: 400 / batch: 600 / lrRate: 1.0 / regStr: 0.001 ]:  0.574
# [Layers: 400 / batch: 600 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.578
# [Layers: 400 / batch: 600 / lrRate: 1.0 / regStr: 1e-06 ]:  0.575
# [Layers: 400 / batch: 700 / lrRate: 0.8 / regStr: 0.001 ]:  0.583
# [Layers: 400 / batch: 700 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.589
# [Layers: 400 / batch: 700 / lrRate: 0.8 / regStr: 1e-06 ]:  0.594
# [Layers: 400 / batch: 700 / lrRate: 0.9 / regStr: 0.001 ]:  0.591
# [Layers: 400 / batch: 700 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.57
# [Layers: 400 / batch: 700 / lrRate: 0.9 / regStr: 1e-06 ]:  0.566
# [Layers: 400 / batch: 700 / lrRate: 1.0 / regStr: 0.001 ]:  0.591
# [Layers: 400 / batch: 700 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.577
# [Layers: 400 / batch: 700 / lrRate: 1.0 / regStr: 1e-06 ]:  0.562
# [Layers: 400 / batch: 800 / lrRate: 0.8 / regStr: 0.001 ]:  0.578
# [Layers: 400 / batch: 800 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.599
# [Layers: 400 / batch: 800 / lrRate: 0.8 / regStr: 1e-06 ]:  0.55
# [Layers: 400 / batch: 800 / lrRate: 0.9 / regStr: 0.001 ]:  0.563
# [Layers: 400 / batch: 800 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.583
# [Layers: 400 / batch: 800 / lrRate: 0.9 / regStr: 1e-06 ]:  0.581
# [Layers: 400 / batch: 800 / lrRate: 1.0 / regStr: 0.001 ]:  0.574
# [Layers: 400 / batch: 800 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.561
# [Layers: 400 / batch: 800 / lrRate: 1.0 / regStr: 1e-06 ]:  0.559
# [Layers: 500 / batch: 500 / lrRate: 0.8 / regStr: 0.001 ]:  0.499
# [Layers: 500 / batch: 500 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.526
# [Layers: 500 / batch: 500 / lrRate: 0.8 / regStr: 1e-06 ]:  0.553
# [Layers: 500 / batch: 500 / lrRate: 0.9 / regStr: 0.001 ]:  0.541
# [Layers: 500 / batch: 500 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.561
# [Layers: 500 / batch: 500 / lrRate: 0.9 / regStr: 1e-06 ]:  0.577
# [Layers: 500 / batch: 500 / lrRate: 1.0 / regStr: 0.001 ]:  0.576
# [Layers: 500 / batch: 500 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.592
# [Layers: 500 / batch: 500 / lrRate: 1.0 / regStr: 1e-06 ]:  0.59
# [Layers: 500 / batch: 600 / lrRate: 0.8 / regStr: 0.001 ]:  0.593
# [Layers: 500 / batch: 600 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.585
# [Layers: 500 / batch: 600 / lrRate: 0.8 / regStr: 1e-06 ]:  0.592
# [Layers: 500 / batch: 600 / lrRate: 0.9 / regStr: 0.001 ]:  0.598
# [Layers: 500 / batch: 600 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.62
# [Layers: 500 / batch: 600 / lrRate: 0.9 / regStr: 1e-06 ]:  0.603
# [Layers: 500 / batch: 600 / lrRate: 1.0 / regStr: 0.001 ]:  0.587
# [Layers: 500 / batch: 600 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.585
# [Layers: 500 / batch: 600 / lrRate: 1.0 / regStr: 1e-06 ]:  0.586
# [Layers: 500 / batch: 700 / lrRate: 0.8 / regStr: 0.001 ]:  0.601
# [Layers: 500 / batch: 700 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.592
# [Layers: 500 / batch: 700 / lrRate: 0.8 / regStr: 1e-06 ]:  0.59
# [Layers: 500 / batch: 700 / lrRate: 0.9 / regStr: 0.001 ]:  0.605
# [Layers: 500 / batch: 700 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.589
# [Layers: 500 / batch: 700 / lrRate: 0.9 / regStr: 1e-06 ]:  0.576
# [Layers: 500 / batch: 700 / lrRate: 1.0 / regStr: 0.001 ]:  0.603
# [Layers: 500 / batch: 700 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.601
# [Layers: 500 / batch: 700 / lrRate: 1.0 / regStr: 1e-06 ]:  0.564
# [Layers: 500 / batch: 800 / lrRate: 0.8 / regStr: 0.001 ]:  0.573
# [Layers: 500 / batch: 800 / lrRate: 0.8 / regStr: 0.0005005 ]:  0.602
# [Layers: 500 / batch: 800 / lrRate: 0.8 / regStr: 1e-06 ]:  0.599
# [Layers: 500 / batch: 800 / lrRate: 0.9 / regStr: 0.001 ]:  0.565
# [Layers: 500 / batch: 800 / lrRate: 0.9 / regStr: 0.0005005 ]:  0.543
# [Layers: 500 / batch: 800 / lrRate: 0.9 / regStr: 1e-06 ]:  0.584
# [Layers: 500 / batch: 800 / lrRate: 1.0 / regStr: 0.001 ]:  0.571
# [Layers: 500 / batch: 800 / lrRate: 1.0 / regStr: 0.0005005 ]:  0.58
# [Layers: 500 / batch: 800 / lrRate: 1.0 / regStr: 1e-06 ]:  0.589
# Best validation accuracy achieved during cross-validation: 0.620000
# with 500 layers, learning rate=0.900000, regularization strength=0.000500

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.575

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
